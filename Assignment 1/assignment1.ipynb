# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

dataset = pd.read_csv('used_cars_data.csv')
dataset
# Out:
#       S.No.                                               Name    Location  \
# 0         0                             Maruti Wagon R LXI CNG      Mumbai
# 1         1                   Hyundai Creta 1.6 CRDi SX Option        Pune
# 2         2                                       Honda Jazz V     Chennai
# 3         3                                  Maruti Ertiga VDI     Chennai
# 4         4                    Audi A4 New 2.0 TDI Multitronic  Coimbatore
# ...     ...                                                ...         ...
# 7248   7248                  Volkswagen Vento Diesel Trendline   Hyderabad
# 7249   7249                             Volkswagen Polo GT TSI      Mumbai
# 7250   7250                             Nissan Micra Diesel XV     Kolkata
# 7251   7251                             Volkswagen Polo GT TSI        Pune
# 7252   7252  Mercedes-Benz E-Class 2009-2013 E 220 CDI Avan...       Kochi
#
# ...

# %%
from datetime import date
date.today().year
dataset['Car_Age']=date.today().year-dataset['Year']
dataset.head()
# Out:
#    S.No.                              Name    Location  Year  \
# 0      0            Maruti Wagon R LXI CNG      Mumbai  2010
# 1      1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 2      2                      Honda Jazz V     Chennai  2011
# 3      3                 Maruti Ertiga VDI     Chennai  2012
# 4      4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
#
#    Kilometers_Driven Fuel_Type Transmission Owner_Type     Mileage   Engine  \
# 0              72000       CNG       Manual      First  26.6 km/kg   998 CC
# 1              41000    Diesel       Manual      First  19.67 kmpl  1582 CC
# 2              46000    Petrol       Manual      First   18.2 kmpl  1199 CC
# 3              87000    Diesel       Manual      First  20.77 kmpl  1248 CC
# 4              40670    Diesel    Automatic     Second   15.2 kmpl  1968 CC
#
#        Power  Seats  New_Price  Price  Car_Age
# 0  58.16 bhp    5.0        NaN   1.75       15
# ...

# %%
dataset['Brand'] = dataset.Name.str.split().str.get(0)
dataset['Model'] = dataset.Name.str.split().str.get(1) + dataset.Name.str.split().str.get(2)
dataset[['Name','Brand','Model']]
# Out:
#                                                    Name          Brand  \
# 0                                Maruti Wagon R LXI CNG         Maruti
# 1                      Hyundai Creta 1.6 CRDi SX Option        Hyundai
# 2                                          Honda Jazz V          Honda
# 3                                     Maruti Ertiga VDI         Maruti
# 4                       Audi A4 New 2.0 TDI Multitronic           Audi
# ...                                                 ...            ...
# 7248                  Volkswagen Vento Diesel Trendline     Volkswagen
# 7249                             Volkswagen Polo GT TSI     Volkswagen
# 7250                             Nissan Micra Diesel XV         Nissan
# 7251                             Volkswagen Polo GT TSI     Volkswagen
# 7252  Mercedes-Benz E-Class 2009-2013 E 220 CDI Avan...  Mercedes-Benz
#
#                  Model
# 0               WagonR
# 1             Creta1.6
# 2                JazzV
# ...

# %%
print(dataset.Brand.unique())
print(dataset.Brand.nunique())
# Out:
# ['Maruti' 'Hyundai' 'Honda' 'Audi' 'Nissan' 'Toyota' 'Volkswagen' 'Tata'
#  'Land' 'Mitsubishi' 'Renault' 'Mercedes-Benz' 'BMW' 'Mahindra' 'Ford'
#  'Porsche' 'Datsun' 'Jaguar' 'Volvo' 'Chevrolet' 'Skoda' 'Mini' 'Fiat'
#  'Jeep' 'Smart' 'Ambassador' 'Isuzu' 'ISUZU' 'Force' 'Bentley'
#  'Lamborghini' 'Hindustan' 'OpelCorsa']
# 33

# %%
searchfor = ['Isuzu' ,'ISUZU','Mini','Land']
dataset[dataset.Brand.str.contains('|'.join(searchfor))].head(5)
# Out:
#      S.No.                                 Name    Location  Year  \
# 13      13     Land Rover Range Rover 2.2L Pure       Delhi  2014
# 14      14       Land Rover Freelander 2 TD4 SE        Pune  2012
# 176    176             Mini Countryman Cooper D      Jaipur  2017
# 191    191  Land Rover Range Rover 2.2L Dynamic  Coimbatore  2018
# 228    228            Mini Cooper Convertible S       Kochi  2017
#
#      Kilometers_Driven Fuel_Type Transmission Owner_Type     Mileage   Engine  \
# 13               72000    Diesel    Automatic      First   12.7 kmpl  2179 CC
# 14               85000    Diesel    Automatic     Second    0.0 kmpl  2179 CC
# 176               8525    Diesel    Automatic     Second   16.6 kmpl  1998 CC
# 191              36091    Diesel    Automatic      First   12.7 kmpl  2179 CC
# 228              26327    Petrol    Automatic      First  16.82 kmpl  1998 CC
#
#           Power  Seats   New_Price  Price  Car_Age Brand              Model
# ...

# %%
dataset["Brand"].replace({"ISUZU": "Isuzu", "Mini": "Mini Cooper","Land":"Land Rover"}, inplace=True)

# %%
dataset.describe().T
# Out:
#                     count          mean           std      min      25%  \
# S.No.              7253.0   3626.000000   2093.905084     0.00   1813.0
# Year               7253.0   2013.365366      3.254421  1996.00   2011.0
# Kilometers_Driven  7253.0  58699.063146  84427.720583   171.00  34000.0
# Seats              7200.0      5.279722      0.811660     0.00      5.0
# Price              6019.0      9.479468     11.187917     0.44      3.5
# Car_Age            7253.0     11.634634      3.254421     6.00      9.0
#
#                         50%       75%        max
# S.No.               3626.00   5439.00     7252.0
# Year                2014.00   2016.00     2019.0
# Kilometers_Driven  53416.00  73000.00  6500000.0
# Seats                  5.00      5.00       10.0
# Price                  5.64      9.95      160.0
# Car_Age               11.00     14.00       29.0

# %%
dataset.describe(include='all').T
# Out:
#                     count unique                     top  freq          mean  \
# S.No.              7253.0    NaN                     NaN   NaN        3626.0
# Name                 7253   2041  Mahindra XUV500 W8 2WD    55           NaN
# Location             7253     11                  Mumbai   949           NaN
# Year               7253.0    NaN                     NaN   NaN   2013.365366
# Kilometers_Driven  7253.0    NaN                     NaN   NaN  58699.063146
# Fuel_Type            7253      5                  Diesel  3852           NaN
# Transmission         7253      2                  Manual  5204           NaN
# Owner_Type           7253      4                   First  5952           NaN
# Mileage              7251    450               17.0 kmpl   207           NaN
# Engine               7207    150                 1197 CC   732           NaN
# Power                7207    386                  74 bhp   280           NaN
# ...

# %%
cat_cols=dataset.select_dtypes(include=['object']).columns
num_cols = dataset.select_dtypes(include=np.number).columns.tolist()
print("Categorical Variables:")
print(cat_cols)
print("Numerical Variables:")
print(num_cols)
# Out:
# Categorical Variables:
# Index(['Name', 'Location', 'Fuel_Type', 'Transmission', 'Owner_Type',
#        'Mileage', 'Engine', 'Power', 'New_Price'],
#       dtype='object')
# Numerical Variables:
# ['S.No.', 'Year', 'Kilometers_Driven', 'Seats', 'Price']

# %%
for col in num_cols:
    print(col)
    print('Skew :', round(dataset[col].skew(), 2))
    plt.figure(figsize = (15, 4))
    plt.subplot(1, 2, 1)
    dataset[col].hist(grid=False)
    plt.ylabel('count')
    plt.subplot(1, 2, 2)
    sns.boxplot(x=dataset[col])
    plt.show()
# Out:
# S.No.
# Skew : 0.0
# Year
# Skew : -0.84
# Kilometers_Driven
# Skew : 61.58
# Seats
# Skew : 1.9
# Price
# Skew : 3.34

# %%
dataset['Brand'] = dataset.Name.str.split().str.get(0)

# %%
dataset['Model'] = dataset.Name.str.split().str.get(1) + dataset.Name.str.split().str.get(2)

# %%
fig, axes = plt.subplots(3, 2, figsize = (18, 18))
fig.suptitle('Bar plot for all categorical variables in the dataset')
sns.countplot(ax = axes[0, 0], x = 'Fuel_Type', data = dataset, color = 'blue', 
              order = dataset['Fuel_Type'].value_counts().index);
sns.countplot(ax = axes[0, 1], x = 'Transmission', data = dataset, color = 'blue', 
              order = dataset['Transmission'].value_counts().index);
sns.countplot(ax = axes[1, 0], x = 'Owner_Type', data = dataset, color = 'blue', 
              order = dataset['Owner_Type'].value_counts().index);
sns.countplot(ax = axes[1, 1], x = 'Location', data = dataset, color = 'blue', 
              order = dataset['Location'].value_counts().index);
sns.countplot(ax = axes[2, 0], x = 'Brand', data = dataset, color = 'blue', 
              order = dataset['Brand'].head(20).value_counts().index);
sns.countplot(ax = axes[2, 1], x = 'Model', data = dataset, color = 'blue', 
              order = dataset['Model'].head(20).value_counts().index);
axes[1][1].tick_params(labelrotation=45);
axes[2][0].tick_params(labelrotation=90);
axes[2][1].tick_params(labelrotation=90);
